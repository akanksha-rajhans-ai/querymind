# %% [markdown]
# # QueryMind Eval Results
#
# MVP eval for six deterministic text-to-SQL smoke cases. The current local run reports 100% pass rate on expected SQL fragments, expected output columns, and non-empty results.

# %%
from pathlib import Path
from app.querymind.evaluator import run_eval

run_eval(Path('data/eval_questions.json'))
